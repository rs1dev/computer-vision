# %% [markdown]
# # CSCI-UA 0480-042 Computer Vision
# ## Homework 3

# %% [markdown]
# Enter your name and NetID below.
#
# #### Name: Riya Singh
# #### NetID: rs6854

# %% [markdown]
# The main goals of this assignment include:
#
# 1. Giving an introduction to Mask-RCNN
# 2. Training the predictors for a given dataset
# 3. Finetuning the entire network for the same dataset
#
# Also accompanying each part, there are a few questions (**12 questions in total**) -- 11 mandatory + 1 extra credit. The first 11 questions are worth 100 points and the extra credit question is worth 10 points.
#
# Please give your answers in the space provided. This homework has a mix of conceptual and coding questions. You can quickly navigate to coding questions by searching (Ctrl/Cmd-F) for `TODO:`.

# %% [markdown]
# # 1. Introduction to Mask-RCNN

# %% [markdown]
# [Mask-RCNN](https://arxiv.org/pdf/1703.06870.pdf) is a network used for instance segmentation. Instance segmentation can be thought of as a hybrid of semantic segmentation and object detection. In other words, we don't want to just find the bounding boxes for each object in our image, we're also interested in finding the segmentation mask of *each object instance*.
#
# ![Instance Segmentation as a Hybrid of Semantic Segmentation and Object Detection](../shared/HW3/img/instance_segmentation.png)
#
# Image Credits: https://towardsdatascience.com/single-stage-instance-segmentation-a-review-1eeb66e0cc49

# %% [markdown]
# Mask-RCNN is built on top of Faster-RCNN, which is a network used for object detection. Faster-RCNN has 2 outputs for each candidate object (Region of Interest or RoI) - a class label and a bounding box offset. Mask-RCNN adds a third branch to Faster-RCNN for predicting segmentation masks on each RoI.

# %% [markdown]
# We'll first briefly go over Faster-RCNN. Faster-RCNN has 2 stages:
#
# 1. **Region Proposal Network (RPN):** Given the image, it proposes candidate object bounding boxes. Previous object detection models such as RCNN and Fast-RCNN handled this separately from the CNN model. Faster-RCNN takes a different approach -- it integrates these two components into the same network to achieve speedup.
# 2. **Fast-RCNN:** This stages takes each candidate RoI and extracts features from the image feature vector using RoIPool. Using these RoI features, it performs classification and bounding box regression.

# %% [markdown]
# ![Mask-RCNN framework for instance segmentation](../shared/HW3/img/mask_rcnn_architecture.png)

# %% [markdown]
# Mask-RCNN has the same 2-stage procedure, but in the 2nd stage, instead of just predicting the classification label and the bounding box offset, it predicts **in parallel** a binary mask for each RoI.
#
# Mask-RCNN relies on a pretrained network (called the "backbone" in the paper) to extract features from the image. These features are fed into the Region Proposal Network (RPN) to generate candidate RoIs. For each RoI candidate, a fixed size RoI feature vector is generated using an RoIAlign layer. This RoI feature map is then provided to the classifier, bounding box predictor and the segmentation mask to generate the final output.

# %% [markdown]
# ## Question 1 [10%]
#
# Training uses a multi-task loss function. What are the three components in this loss function? Is the loss computed per image or per RoI?

# %% [markdown]
# #### Answer :
# The three components of the multi-task loss function for Mask R-CNN are the classification loss ($\mathcal{L_{cls}}$), bounding-box regression loss ($\mathcal{L_{box}}$), and mask branch loss ($\mathcal{L_{mask}}$). $\mathcal{L_{cls}}$ and $\mathcal{L_{box}}$ are handled in the same way as the loss function of Faster R-CNN. $\mathcal{L_{mask}}$ is the average binary cross-entropy loss and is only defined on the *k-th* mask of an RoI associated with ground-truth class *k*.
# The total multi-task loss function is found by summing these 3 losses. $$ \mathcal{L} = \mathcal{L_{cls}} + \mathcal{L_{box}} + \mathcal{L_{mask}}$$
# The loss is computed on each RoI of an image and the RoI's are determined by the Region Proposal Network (RPN).

# %% [markdown]
# ## Question 2 [5%]
# [This blog post](https://lilianweng.github.io/lil-log/2017/12/31/object-recognition-for-dummies-part-3.html) by Lilian Weng gives a nice overview of the object detection (RCNN type) networks. In the blog post, it is mentioned that Mask-RCNN uses RoIAlign instead of RoIPool. Explain briefly in 3-4 lines why this is being done.

# %% [markdown]
# #### Answer :
# Mask-RCNN uses RoIAlign instead of RoIPool because RoIAlign leads to improved results by avoiding the pixel-to-pixel misalignment and data loss that results from RoIPool. RoIPool uses spatial quantization to round the stride dimension to the nearest integer, but RoIAlign allows for non-integer values using a quantization-free layer and bilinear interpolation to compute the exact values of the input features. Thus, the extracted features are properly aligned with the input and RoIAlign allows for the RoI's to be more precisely mapped to the regions of the original image.

# %% [markdown]
# ## Question 3 [5%]
# What are the different backbones explored in the Mask-RCNN paper? They are denoted in the paper using network-depth-features nomenclature. What is the advantage of using a ResNet-FPN backbone over a ResNet-C4 backbone for feature extraction?

# %% [markdown]
# #### Answer :
#
# The different backbones in the Mask-RCNN paper are ResNet, ResNeXt, and ResNet-FPN networks of 50 or 101 layers. From the ablation experiments, it appears that the deeper ResNet backbone (101 layers) and more advanced designed like FPN and ResNeXt produce better results for Mask R-CNN.
#
# ResNet-C4 (aka ResNet-50-C4) network extracts features from the final convolutional layer of the 4th stage with ResNet-50. ResNet-FPN (ResNet with feature pyramid network) has some advantages like multi-layer RoI generation which generate RoI of different scales. This appears to give excellent gains in accuracy and speed for feature extraction.

# %% [markdown]
# # 2. Training the Predictors for a New Dataset

# %% [markdown]
# In this section, we'll start with a pretrained Mask-RCNN model that uses Resnet-50-FPN as the backbone. This model was trained on MS-COCO dataset which is widely used for multiple vision tasks such as object detection, instance segmentation, etc.
#
# MS-COCO has 91 classes (90 for objects + 1 for background). Some sample objects in the dataset include `person`, `car`, `bicycle`, `knife`, `train`, etc.
#
# Along with this homework file, we have also provided another sample dataset (we'll refer to it as the [Nature dataset](https://towardsdatascience.com/custom-instance-segmentation-training-with-7-lines-of-code-ff340851e99b)). It isn't a standard dataset, but it's small enough (600 train + 200 test images) and allows us to easily demo finetuning a pretrained Mask-RCNN model. This dataset contains only 2 classes - `squirrel` and `butterfly`.
#
# Our goal in part2 and part3 of this assignment is to take the pretrained Mask-RCNN model and finetune/train it for this dataset. However, here in part2, instead of finetuning the entire network, we'll train only the final layers.
#
# In Homework 2, we've shown how one could feed data into the network using `Dataset`s and `DataLoader`s. We'll use the same strategy here for finetuning the model.
#
# We've based this homework on this [PyTorch tutorial on Object Detection Finetuning](https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html).

# %% [markdown]
# ## Question 4 [25%]
#
# Complete the TODO section in below cell. Specifically:
#
# 1. Read image height, width and polygon shapes data from the JSON file.
# 2. Generate 2D masks from the polygon points. You can follow this idea: https://stackoverflow.com/a/3732128
# 3. Generate the bounding boxes from the mask data. Assume that the bounding box is a rectangle with the smallest area enclosing the mask.
#
# You may find this json schema useful:
# ```
# {
#    "shapes": [ # list of object instances; masks are represented as polygons
#        ## data for instance1
#        {
#            "label": "" # label for instance1
#            "points": [] # 2d list of polygon points [(x1, y1), (x2, y2), ..]
#        },
#        ## data for instance2
#        {
#            "label": []
#            "points": []
#        },
#
#        ..
#        ..
#    ],
#    "imagePath": ""
#    "imageData" : ""
#    "imageHeight": <integer>
#    "imageWidth": <integer>
# }
# ```

# %%
# Alternatively, you could also uncomment the line below to see a sample json file
# !cat '../shared/data/HW3/nature/train/s (3).json'
# Out:
# }

# %%
import numpy as np
import torch
import torchvision

import json # for reading from json file
import glob # for listing files inside a folder
from PIL import Image, ImageDraw # for reading images and drawing masks on them.

from torchvision.utils import draw_bounding_boxes

# Create a custom dataset class for Nature
# dataset subclassing PyTorch's Dataset class
class NatureDataset(torch.utils.data.Dataset):
    def __init__(self, root, transforms):
        self.transforms = transforms

        # Load all image files, sorting them to
        # ensure that they are aligned with json files
        imgs = glob.glob(root + '/*.jpg')
        imgs += glob.glob(root + '/*.png') # some images are in png format
        self.imgs = sorted(imgs)
        
        # Mask data is stored in a json file
        masks = glob.glob(root + '/*.json')
        self.masks = sorted(masks)
        
        # Each image can have multiple object instances, and each
        # instance is associated with either of these 2 labels.

        # Need to convert str-labels to ids. So we'll use 
        # this label-to-index mapping.
        # Note: we can't start from 0 because 0 is restricted
        # to the "background" class
        self.label_to_id = {'squirrel': 1, 'butterfly': 2}
        
    def __getitem__(self, idx):
        # Have already aligned images and JSON files; can now
        # simply use the index to access both images and masks
        img_path = self.imgs[idx]
        mask_path = self.masks[idx]
        
        # Read image using PIL.Image and convert it to an RGB image
        img = Image.open(img_path).convert("RGB")
        
        # TODO: Read image height, width and mask data from
        # the JSON file
        with open(mask_path, 'r') as fp:
            # TODO: Using json library read the dictionary
            # from the fp
            json_dict = json.load(fp)
            
            # TODO:
            height = json_dict["imageHeight"]
            
            # TODO:
            width = json_dict["imageWidth"]
            
            # TODO:
            poly_shapes_data = json_dict["shapes"]
            #poly_shapes_data = [] #[[[], [], []], [[], [], []], [[], [], []]]
            #for shape in json_dict["shapes"]:
             #   points_group = shape["points"] 
              #  poly_shapes_data.append(points_group)
        
        # TODO: Each image can have multiple mask instances.
        # Using the polygon points, generate the 2d-mask
        # using PIL's ImageDraw.polygon
        masks = []
        labels = []
        for shape_data in poly_shapes_data: #[[(), (), ()], [(), (), ()]]
            polygon_points = [tuple(point) for point in shape_data['points']]
            
            # TODO: Using Image.new() create an image of size (width, height)
            # and fill it with 0s.
            mask_img = Image.new('L', (width, height), 0)
            #mask_img = PIL.Image.new(mode="RGB", size=(200, 200))
            
            # TODO: Draw the mask on the base image we just created
            ImageDraw.Draw(mask_img).polygon(polygon_points, outline=1, fill=1)

            mask = np.array(mask_img)
            masks.append(mask)

            label = shape_data['label']
            labels.append(label)
        
        # Each mask instance also has an associated label which is str-type
        # Convert the str into an int using the mapping we created in __init__
        labels = [self.label_to_id[label] for label in labels]
        
        # TODO: Generate the bounding boxes for each instance
        # from the 2d masks
        num_objs = len(masks)
        boxes = []
        for i in range(num_objs):
            # TODO: Use np.where() to find where mask[i] == True.
            # pos will be a 2d-list of indices
            pos = np.where(masks[i]== True)
            # In pos, find the min x- and y- indices;
            # max x- and y- indices. This will give us our box bounds.
            
            # TODO:
            xmin = np.min(pos[1])
            
            # TODO:
            xmax = np.max(pos[1])
            
            # TODO:
            ymin = np.min(pos[0])
            
            # TODO:
            ymax = np.max(pos[0])
            
            boxes.append([xmin, ymin, xmax, ymax])   
            
        # Convert everything into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        masks = torch.as_tensor(masks, dtype=torch.uint8)

        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # Assume all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["masks"] = masks
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd
        
        # Apply transforms
        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    
    def __len__(self):
        return len(self.imgs)

# %% [markdown]
# Having implemented our `NatureDataset` class, let's create the `Dataset` and the `DataLoader` objects. Note that we're not using `torchvision.transforms`, instead we're using transforms provided in a separate script in this directory called `transforms.py`.

# %%
import transforms as T

def get_transform(train):
    transforms = []
    transforms.append(T.ToTensor())
    if train:
        transforms.append(T.RandomHorizontalFlip(0.5))
    return T.Compose(transforms)

# use our dataset and defined transformations
dataset = NatureDataset('../shared/data/HW3/nature/train', get_transform(train=True))
dataset_test = NatureDataset('../shared/data/HW3/nature/test', get_transform(train=False))

import utils

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=2, shuffle=True,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=1, shuffle=False,
    collate_fn=utils.collate_fn)

# %% [markdown]
# Now let's visualize one image from our dataset.

# %%
import matplotlib.pyplot as plt

#img, targets = dataset[50]
img, targets = dataset[506]

# np.transpose docs: https://numpy.org/doc/stable/reference/generated/numpy.transpose.html
# img is a PyTorch tensor, can convert it to a NumPy tensor by calling .numpy() on it.
plt.imshow(np.transpose(img.numpy(), (1, 2, 0)));

# %% [markdown]
# And here's the corresponding mask.

# %%
plt.imshow(np.transpose(targets['masks'].numpy(), (1, 2, 0)), interpolation='none');

# %% [markdown]
# We'll be training the final layers of the pretrained Mask-RCNN model (with Resnet-50-FPN backbone) available in the `torchvision` package. So let's download the model:

# %%
model_p2 = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)

# %% [markdown]
# ## Question 5 [5%]
#
# Recall what we said earlier: For training for the new dataset, we need to modify its box predictor (FastRCNNPredictor) and its mask predictor (MaskRCNNPredictor) to match with the new dataset. Complete the code cell below.
#
# You may find these docs for `FastRCNNPredictor` and `MaskRCNNPredictor` useful:
#
# ![FastRCNNPredictor Docs](../shared/HW3/img/FastRCNNPredictor_docs.png)
# ![MaskRCNNPredictor Docs](../shared/HW3/img/MaskRCNNPredictor_docs.png)

# %%
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

# Our new dataset has 3 classes: butterfly, squirrel and background
num_classes = 3

# Get number of input features for the classifier
in_features = model_p2.roi_heads.box_predictor.cls_score.in_features
#print(in_features) #1024

# TODO: replace the pre-trained head with a new one
model_p2.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

# Get number of input features for the mask predictor
in_features_mask = model_p2.roi_heads.mask_predictor.conv5_mask.in_channels
hidden_layer = 256
#print(in_features_mask) #256

# TODO: replace the mask predictor with a new one
model_p2.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask, hidden_layer, num_classes)

# %% [markdown]
# Training these layers can take several minutes on a CPU, so we've provided GPUs to make this faster. It should take ~5 mins to run the training in Q7. But before that, we want to ensure that PyTorch is able to access the GPU by printing the device PyTorch is currently (prints `cuda` if it's using a GPU, otherwise it prints `cpu`).
#
# Now we want to freeze all the layers below these predictors. We can do this by setting the `.requires_grad` attribute of the parameters we want to freeze to `False`. Read more about `requires_grad` from [this PyTorch page on Autograd mechanics](https://pytorch.org/docs/stable/notes/autograd.html#excluding-subgraphs-from-backward).
#
# In order to do the computation on a GPU, we have to move the model from main memory to GPU memory. This can be done by simply calling `.to(device)` on the model. See [the docs](https://pytorch.org/docs/stable/generated/torch.nn.Module.html#torch.nn.Module.to) for more information.

# %% [markdown]
# ### Note : Make sure the below prints `Using : cuda` before proceeding further. If it doesn't print cuda , make sure you are in the GPU profile of the server. To start the server in GPU profile, shutdown the current server and restart the server by selecting the GPU option.

# %%
import itertools

# Freeze model and move it to device
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print("Using : ", device)

for param in model_p2.parameters():
    param.requires_grad = False

pred_params = itertools.chain(
    model_p2.roi_heads.mask_predictor.parameters(),
    model_p2.roi_heads.box_predictor.parameters()
)

for param in pred_params:
    param.requires_grad = True

model_p2 = model_p2.to(device)
# Out:
# Using :  cuda

# %% [markdown]
# We were able to verify that PyTorch is able to access a GPU. Now let's see the layers inside the `model_p2.roi_heads` to understand what we have modified here (we just modified `box_predictor` and `mask_predictor`). You could also verify the output below from figure 4 in the Mask-RCNN paper. You'll notice that it's the exact same network on the right part of that figure.

# %% [markdown]
# We can use below command to check what are the GPU devices that are available to us and their current memory usage. Having a GPU in the list doesn't mean we can simply use it for training. We need to have proper CUDA drivers and compatible versions of pytorch/torchvision libraries. We have made sure that the versions are compatible and one is able to use GPU without and additional changes.

# %%
# !nvidia-smi
# Out:
# Mon Nov 28 23:50:48 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.172.01   Driver Version: 450.172.01   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P0    30W /  70W |   5996MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
model_p2.roi_heads
# Out:
# RoIHeads(
#   (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#   (box_head): TwoMLPHead(
#     (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#     (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#   )
#   (box_predictor): FastRCNNPredictor(
#     (cls_score): Linear(in_features=1024, out_features=3, bias=True)
#     (bbox_pred): Linear(in_features=1024, out_features=12, bias=True)
#   )
#   (mask_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(14, 14), sampling_ratio=2)
#   (mask_head): MaskRCNNHeads(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (1): Conv2dNormActivation(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (2): Conv2dNormActivation(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (3): Conv2dNormActivation(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
#   (mask_predictor): MaskRCNNPredictor(
#     (conv5_mask): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#     (relu): ReLU(inplace=True)
#     (mask_fcn_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %% [markdown]
# ## Question 6 [10%]
# We just printed the head architecture. From the above output, list all the layers we're training along their names.
#
# For example, if we're training mask_fcn1 of mask_head you'll specify:
#
# `mask_head.mask_fcn1`: 2d-Conv layer with 256 input channels, 256 output channels and kernel size = (2, 2).
#
# Note: We're **only** asking for layers with trainable parameters.

# %% [markdown]
# #### Answer:
#
#
# 1. box_predictor.cls_score: Linear layer with 1024 input features, 3 output features, and bias of True.
#
# 2. box_predictor.bbox_pred: Linear layer with 1024 input features, 12 output features, and bias of True.
#
# 3. mask_predictor.conv5_mask: 2d-ConvTranspose layer with 256 input channels, 256 output channels, kernel size = (2, 2), and default bias of True.
#
# 4. mask_predictor.mask_fcn_logits: 2d-Conv layer with 256 input channels, 3 output channels, kernel size = (1, 1), and default bias of True.

# %% [markdown]
# Both the dataloaders and model have been prepared for training. All that remains is to set an optimizer and a learning rate scheduler. When we create an optimizer, we have to provide it the list of trainable parameters.

# %%
# Declare optimizer and lr
params = [p for p in model_p2.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                step_size=3,
                                                gamma=0.1)

# %% [markdown]
# ## Question 7 [10%]
#
# How many trainable parameters are we passing to the optimizer?
#
# Here's an example to calculate # of trainable parameters in a fully connected layer with:
# 1. an additive bias
# 2. in_channels = 1024
# 3. out_channels = 10
#
# The number of trainable parameters here will be 1024\*10 + 10 = 10250.

# %% [markdown]
# #### Answer :
#
# |  Training Layers (q6) | Number of Trainable Parameters
# | :-: | :-:
# |   box_predictor.cls_score (Linear)  | (1024 * 3) + 3 = 3075
# |  box_predictor.bbox_pred (Linear)   | (1024 * 12) + 12= 12300
# |  conv5_mask (ConvTranspose2d)  | (256 * 256) + 256 = 65792
# |  mask_predictor.mask_fcn_logits (conv2d)  | (256 * 3) + 3 = 771
#
# Total trainable parameters = 3075 + 12300 + 65792 + 771 = 81,938

# %% [markdown]
# Now we can finally start the training process.

# %%
num_epochs = 3

from engine import train_one_epoch, evaluate

for epoch in range(num_epochs):
    print("Epoch", epoch)
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model_p2, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model_p2, data_loader_test, device=device)
# Out:
# Epoch 0
# Epoch: [0]  [  0/300]  eta: 0:01:47  lr: 0.000022  loss: 6.2361 (6.2361)  loss_classifier: 0.9971 (0.9971)  loss_box_reg: 0.0978 (0.0978)  loss_mask: 5.0644 (5.0644)  loss_objectness: 0.0033 (0.0033)  loss_rpn_box_reg: 0.0735 (0.0735)  time: 0.3577  data: 0.0204  max mem: 1785
# Epoch: [0]  [ 10/300]  eta: 0:01:20  lr: 0.000189  loss: 4.3474 (4.0733)  loss_classifier: 0.8618 (0.8566)  loss_box_reg: 0.1426 (0.1515)  loss_mask: 3.1945 (3.0474)  loss_objectness: 0.0019 (0.0024)  loss_rpn_box_reg: 0.0055 (0.0154)  time: 0.2774  data: 0.0149  max mem: 1785
# Epoch: [0]  [ 20/300]  eta: 0:01:14  lr: 0.000356  loss: 2.0575 (2.8550)  loss_classifier: 0.5023 (0.5950)  loss_box_reg: 0.1426 (0.1565)  loss_mask: 1.3808 (2.0859)  loss_objectness: 0.0027 (0.0036)  loss_rpn_box_reg: 0.0053 (0.0140)  time: 0.2614  data: 0.0150  max mem: 1785
# Epoch: [0]  [ 30/300]  eta: 0:01:10  lr: 0.000523  loss: 1.0901 (2.2717)  loss_classifier: 0.1858 (0.4585)  loss_box_reg: 0.1456 (0.1601)  loss_mask: 0.7566 (1.6341)  loss_objectness: 0.0041 (0.0041)  loss_rpn_box_reg: 0.0065 (0.0148)  time: 0.2536  data: 0.0151  max mem: 1785
# Epoch: [0]  [ 40/300]  eta: 0:01:08  lr: 0.000690  loss: 0.9100 (1.9618)  loss_classifier: 0.1560 (0.3904)  loss_box_reg: 0.1485 (0.1621)  loss_mask: 0.6274 (1.3909)  loss_objectness: 0.0060 (0.0055)  loss_rpn_box_reg: 0.0057 (0.0129)  time: 0.2605  data: 0.0148  max mem: 1785
# Epoch: [0]  [ 50/300]  eta: 0:01:05  lr: 0.000857  loss: 0.9620 (1.7986)  loss_classifier: 0.1496 (0.3421)  loss_box_reg: 0.1377 (0.1565)  loss_mask: 0.6326 (1.2817)  loss_objectness: 0.0048 (0.0054)  loss_rpn_box_reg: 0.0057 (0.0129)  time: 0.2667  data: 0.0145  max mem: 1785
# Epoch: [0]  [ 60/300]  eta: 0:01:03  lr: 0.001024  loss: 0.8525 (1.6311)  loss_classifier: 0.1123 (0.3066)  loss_box_reg: 0.1192 (0.1532)  loss_mask: 0.5773 (1.1530)  loss_objectness: 0.0028 (0.0051)  loss_rpn_box_reg: 0.0092 (0.0132)  time: 0.2720  data: 0.0143  max mem: 1785
# Epoch: [0]  [240/300]  eta: 0:00:16  lr: 0.004031  loss: 0.5630 (0.8874)  loss_classifier: 0.0467 (0.1269)  loss_box_reg: 0.0781 (0.1234)  loss_mask: 0.4116 (0.6190)  loss_objectness: 0.0050 (0.0052)  loss_rpn_box_reg: 0.0097 (0.0129)  time: 0.2803  data: 0.0144  max mem: 1785
# Epoch: [0]  [250/300]  eta: 0:00:13  lr: 0.004198  loss: 0.5451 (0.8759)  loss_classifier: 0.0454 (0.1237)  loss_box_reg: 0.0842 (0.1218)  loss_mask: 0.4116 (0.6121)  loss_objectness: 0.0057 (0.0053)  loss_rpn_box_reg: 0.0055 (0.0130)  time: 0.2636  data: 0.0130  max mem: 1785
# Epoch: [0]  [260/300]  eta: 0:00:10  lr: 0.004365  loss: 0.5188 (0.8632)  loss_classifier: 0.0426 (0.1207)  loss_box_reg: 0.0741 (0.1200)  loss_mask: 0.3720 (0.6043)  loss_objectness: 0.0051 (0.0053)  loss_rpn_box_reg: 0.0054 (0.0128)  time: 0.2501  data: 0.0129  max mem: 1785
# Epoch: [0]  [270/300]  eta: 0:00:08  lr: 0.004532  loss: 0.5472 (0.8554)  loss_classifier: 0.0475 (0.1190)  loss_box_reg: 0.0735 (0.1194)  loss_mask: 0.3950 (0.5985)  loss_objectness: 0.0055 (0.0056)  loss_rpn_box_reg: 0.0063 (0.0130)  time: 0.2649  data: 0.0147  max mem: 1785
# Epoch: [0]  [280/300]  eta: 0:00:05  lr: 0.004699  loss: 0.4143 (0.8420)  loss_classifier: 0.0440 (0.1163)  loss_box_reg: 0.0735 (0.1177)  loss_mask: 0.2705 (0.5891)  loss_objectness: 0.0054 (0.0056)  loss_rpn_box_reg: 0.0102 (0.0133)  time: 0.2782  data: 0.0154  max mem: 1785
# Epoch: [0]  [290/300]  eta: 0:00:02  lr: 0.004866  loss: 0.4045 (0.8265)  loss_classifier: 0.0440 (0.1138)  loss_box_reg: 0.0741 (0.1163)  loss_mask: 0.2526 (0.5774)  loss_objectness: 0.0032 (0.0056)  loss_rpn_box_reg: 0.0111 (0.0133)  time: 0.2732  data: 0.0138  max mem: 1849
# Epoch: [0]  [299/300]  eta: 0:00:00  lr: 0.005000  loss: 0.3703 (0.8148)  loss_classifier: 0.0426 (0.1116)  loss_box_reg: 0.0813 (0.1149)  loss_mask: 0.2500 (0.5690)  loss_objectness: 0.0049 (0.0058)  loss_rpn_box_reg: 0.0099 (0.0134)  time: 0.2753  data: 0.0132  max mem: 1849
# Epoch: [0] Total time: 0:01:21 (0.2713 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:24  model_time: 0.1129 (0.1129)  evaluator_time: 0.0038 (0.0038)  time: 0.1230  data: 0.0058  max mem: 1849
# Test:  [100/200]  eta: 0:00:12  model_time: 0.1218 (0.1167)  evaluator_time: 0.0045 (0.0049)  time: 0.1342  data: 0.0069  max mem: 1849
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1203 (0.1177)  evaluator_time: 0.0045 (0.0047)  time: 0.1309  data: 0.0074  max mem: 1849
# Test: Total time: 0:00:25 (0.1296 s / it)
# Averaged stats: model_time: 0.1203 (0.1177)  evaluator_time: 0.0045 (0.0047)
# Accumulating evaluation results...
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.854
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.357
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.462
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.433
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.481
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.609
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.612
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.650
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.605
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.496
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.867
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.532
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.408
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.553
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.537
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.672
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.674
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.675
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.676
# Epoch 1
# Epoch: [1]  [  0/300]  eta: 0:01:22  lr: 0.005000  loss: 0.3287 (0.3287)  loss_classifier: 0.0377 (0.0377)  loss_box_reg: 0.0702 (0.0702)  loss_mask: 0.2154 (0.2154)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0051 (0.0051)  time: 0.2757  data: 0.0156  max mem: 1849
# Epoch: [1]  [ 10/300]  eta: 0:01:22  lr: 0.005000  loss: 0.3223 (0.4018)  loss_classifier: 0.0438 (0.0496)  loss_box_reg: 0.0702 (0.0791)  loss_mask: 0.2072 (0.2608)  loss_objectness: 0.0029 (0.0043)  loss_rpn_box_reg: 0.0073 (0.0079)  time: 0.2862  data: 0.0149  max mem: 1849
# Epoch: [1]  [ 20/300]  eta: 0:01:17  lr: 0.005000  loss: 0.3125 (0.3857)  loss_classifier: 0.0355 (0.0451)  loss_box_reg: 0.0659 (0.0725)  loss_mask: 0.1952 (0.2537)  loss_objectness: 0.0030 (0.0043)  loss_rpn_box_reg: 0.0082 (0.0102)  time: 0.2766  data: 0.0146  max mem: 1849
# Epoch: [1]  [ 30/300]  eta: 0:01:13  lr: 0.005000  loss: 0.3208 (0.3782)  loss_classifier: 0.0406 (0.0460)  loss_box_reg: 0.0682 (0.0762)  loss_mask: 0.1973 (0.2429)  loss_objectness: 0.0030 (0.0045)  loss_rpn_box_reg: 0.0058 (0.0087)  time: 0.2618  data: 0.0137  max mem: 1849
# Epoch: [1]  [ 40/300]  eta: 0:01:11  lr: 0.005000  loss: 0.3576 (0.3837)  loss_classifier: 0.0442 (0.0473)  loss_box_reg: 0.0746 (0.0768)  loss_mask: 0.1998 (0.2438)  loss_objectness: 0.0045 (0.0051)  loss_rpn_box_reg: 0.0058 (0.0106)  time: 0.2719  data: 0.0131  max mem: 1849
# Epoch: [1]  [ 50/300]  eta: 0:01:07  lr: 0.005000  loss: 0.3371 (0.3732)  loss_classifier: 0.0354 (0.0462)  loss_box_reg: 0.0613 (0.0736)  loss_mask: 0.2292 (0.2375)  loss_objectness: 0.0033 (0.0051)  loss_rpn_box_reg: 0.0064 (0.0108)  time: 0.2705  data: 0.0138  max mem: 1849
# Epoch: [1]  [ 60/300]  eta: 0:01:06  lr: 0.005000  loss: 0.3569 (0.3784)  loss_classifier: 0.0354 (0.0455)  loss_box_reg: 0.0652 (0.0739)  loss_mask: 0.2390 (0.2434)  loss_objectness: 0.0033 (0.0049)  loss_rpn_box_reg: 0.0064 (0.0109)  time: 0.2796  data: 0.0145  max mem: 1849
).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.500
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.881
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.508
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.493
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.514
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.548
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.660
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.660
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.645
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.664
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.537
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.881
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.615
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.391
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.572
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.668
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.668
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.676
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.669
# Epoch 2
# Epoch: [2]  [  0/300]  eta: 0:01:22  lr: 0.005000  loss: 0.3619 (0.3619)  loss_classifier: 0.0485 (0.0485)  loss_box_reg: 0.0932 (0.0932)  loss_mask: 0.1966 (0.1966)  loss_objectness: 0.0092 (0.0092)  loss_rpn_box_reg: 0.0144 (0.0144)  time: 0.2745  data: 0.0165  max mem: 1849
# Epoch: [2]  [ 10/300]  eta: 0:01:15  lr: 0.005000  loss: 0.3613 (0.3803)  loss_classifier: 0.0370 (0.0439)  loss_box_reg: 0.0622 (0.0705)  loss_mask: 0.2233 (0.2434)  loss_objectness: 0.0061 (0.0070)  loss_rpn_box_reg: 0.0086 (0.0155)  time: 0.2609  data: 0.0132  max mem: 1849
# Epoch: [2]  [ 20/300]  eta: 0:01:13  lr: 0.005000  loss: 0.3248 (0.3657)  loss_classifier: 0.0310 (0.0367)  loss_box_reg: 0.0607 (0.0638)  loss_mask: 0.2233 (0.2443)  loss_objectness: 0.0065 (0.0072)  loss_rpn_box_reg: 0.0062 (0.0136)  time: 0.2631  data: 0.0130  max mem: 1849
# Epoch: [2]  [ 30/300]  eta: 0:01:11  lr: 0.005000  loss: 0.3386 (0.3881)  loss_classifier: 0.0341 (0.0428)  loss_box_reg: 0.0607 (0.0689)  loss_mask: 0.2251 (0.2561)  loss_objectness: 0.0044 (0.0065)  loss_rpn_box_reg: 0.0057 (0.0138)  time: 0.2663  data: 0.0129  max mem: 1849
# Epoch: [2]  [ 40/300]  eta: 0:01:08  lr: 0.005000  loss: 0.3787 (0.4067)  loss_classifier: 0.0402 (0.0441)  loss_box_reg: 0.0675 (0.0694)  loss_mask: 0.2358 (0.2729)  loss_objectness: 0.0034 (0.0068)  loss_rpn_box_reg: 0.0057 (0.0135)  time: 0.2670  data: 0.0137  max mem: 1849
# Epoch: [2]  [ 50/300]  eta: 0:01:06  lr: 0.005000  loss: 0.3200 (0.4050)  loss_classifier: 0.0393 (0.0428)  loss_box_reg: 0.0675 (0.0703)  loss_mask: 0.2131 (0.2719)  loss_objectness: 0.0081 (0.0070)  loss_rpn_box_reg: 0.0057 (0.0130)  time: 0.2696  data: 0.0136  max mem: 1849
# Epoch: [2]  [ 60/300]  eta: 0:01:04  lr: 0.005000  loss: 0.3051 (0.3929)  loss_classifier: 0.0375 (0.0415)  loss_box_reg: 0.0593 (0.0695)  loss_mask: 0.1807 (0.2620)  loss_objectness: 0.0039 (0.0065)  loss_rpn_box_reg: 0.0103 (0.0134)  time: 0.2735  data: 0.0139  max mem: 1849
# Epoch: [2]  [ 70/300]  eta: 0:01:01  lr: 0.005000  loss: 0.3285 (0.3899)  loss_classifier: 0.0375 (0.0428)  loss_box_reg: 0.0645 (0.0711)  loss_mask: 0.2124 (0.2564)  loss_objectness: 0.0029 (0.0063)  loss_rpn_box_reg: 0.0103 (0.0132)  time: 0.2711  data: 0.0150  max mem: 1849
# Epoch: [2]  [ 80/300]  eta: 0:00:59  lr: 0.005000  loss: 0.3781 (0.3956)  loss_classifier: 0.0389 (0.0426)  loss_box_reg: 0.0621 (0.0711)  loss_mask: 0.2319 (0.2614)  loss_objectness: 0.0045 (0.0065)  loss_rpn_box_reg: 0.0085 (0.0140)  time: 0.2706  data: 0.0139  max mem: 1849
# Epoch: [2]  [ 90/300]  eta: 0:00:56  lr: 0.005000  loss: 0.3394 (0.3882)  loss_classifier: 0.0305 (0.0410)  loss_box_reg: 0.0544 (0.0702)  loss_mask: 0.2328 (0.2573)  loss_objectness: 0.0044 (0.0062)  loss_rpn_box_reg: 0.0089 (0.0134)  time: 0.2663  data: 0.0132  max mem: 1849
# Epoch: [2]  [100/300]  eta: 0:00:53  lr: 0.005000  loss: 0.3774 (0.3982)  loss_classifier: 0.0330 (0.0431)  loss_box_reg: 0.0588 (0.0718)  loss_mask: 0.2594 (0.2620)  loss_objectness: 0.0036 (0.0067)  loss_rpn_box_reg: 0.0163 (0.0146)  time: 0.2716  data: 0.0145  max mem: 1849
# Epoch: [2]  [110/300]  eta: 0:00:51  lr: 0.005000  loss: 0.4122 (0.4021)  loss_classifier: 0.0406 (0.0433)  loss_box_reg: 0.0685 (0.0718)  loss_mask: 0.2905 (0.2660)  loss_objectness: 0.0036 (0.0066)  loss_rpn_box_reg: 0.0121 (0.0144)  time: 0.2802  data: 0.0149  max mem: 1849
# Epoch: [2]  [120/300]  eta: 0:00:48  lr: 0.005000  loss: 0.4009 (0.4022)  loss_classifier: 0.0390 (0.0437)  loss_box_reg: 0.0719 (0.0730)  loss_mask: 0.2357 (0.2645)  loss_objectness: 0.0049 (0.0066)  loss_rpn_box_reg: 0.0082 (0.0144)  time: 0.2702  data: 0.0142  max mem: 1849
# Epoch: [2]  [130/300]  eta: 0:00:45  lr: 0.005000  loss: 0.3692 (0.4011)  loss_classifier: 0.0378 (0.0433)  loss_box_reg: 0.0698 (0.0724)  loss_mask: 0.2365 (0.2650)  loss_objectness: 0.0034 (0.0063)  loss_rpn_box_reg: 0.0087 (0.0142)  time: 0.2677  data: 0.0138  max mem: 1849
# Epoch: [2]  [140/300]  eta: 0:00:43  lr: 0.005000  loss: 0.3446 (0.4023)  loss_classifier: 0.0299 (0.0430)  loss_box_reg: 0.0546 (0.0717)  loss_mask: 0.2365 (0.2674)  loss_objectness: 0.0026 (0.0063)  loss_rpn_box_reg: 0.0087 (0.0139)  time: 0.2697  data: 0.0131  max mem: 1849
# Epoch: [2]  [240/300]  eta: 0:00:16  lr: 0.005000  loss: 0.3129 (0.3950)  loss_classifier: 0.0308 (0.0421)  loss_box_reg: 0.0542 (0.0704)  loss_mask: 0.2045 (0.2625)  loss_objectness: 0.0038 (0.0060)  loss_rpn_box_reg: 0.0074 (0.0139)  time: 0.2593  data: 0.0144  max mem: 1849
# Epoch: [2]  [250/300]  eta: 0:00:13  lr: 0.005000  loss: 0.2943 (0.3919)  loss_classifier: 0.0330 (0.0419)  loss_box_reg: 0.0615 (0.0703)  loss_mask: 0.1792 (0.2598)  loss_objectness: 0.0024 (0.0059)  loss_rpn_box_reg: 0.0081 (0.0139)  time: 0.2741  data: 0.0142  max mem: 1849
# Epoch: [2]  [260/300]  eta: 0:00:10  lr: 0.005000  loss: 0.3115 (0.3914)  loss_classifier: 0.0344 (0.0422)  loss_box_reg: 0.0592 (0.0709)  loss_mask: 0.2005 (0.2585)  loss_objectness: 0.0025 (0.0058)  loss_rpn_box_reg: 0.0098 (0.0139)  time: 0.2891  data: 0.0140  max mem: 1849
# Epoch: [2]  [270/300]  eta: 0:00:08  lr: 0.005000  loss: 0.3710 (0.3950)  loss_classifier: 0.0344 (0.0423)  loss_box_reg: 0.0627 (0.0714)  loss_mask: 0.2378 (0.2617)  loss_objectness: 0.0042 (0.0058)  loss_rpn_box_reg: 0.0081 (0.0138)  time: 0.2767  data: 0.0143  max mem: 1849
# Epoch: [2]  [280/300]  eta: 0:00:05  lr: 0.005000  loss: 0.3622 (0.3940)  loss_classifier: 0.0319 (0.0423)  loss_box_reg: 0.0643 (0.0710)  loss_mask: 0.2290 (0.2613)  loss_objectness: 0.0025 (0.0057)  loss_rpn_box_reg: 0.0076 (0.0137)  time: 0.2620  data: 0.0147  max mem: 1849
# Epoch: [2]  [290/300]  eta: 0:00:02  lr: 0.005000  loss: 0.3044 (0.3919)  loss_classifier: 0.0306 (0.0422)  loss_box_reg: 0.0532 (0.0711)  loss_mask: 0.1856 (0.2593)  loss_objectness: 0.0025 (0.0057)  loss_rpn_box_reg: 0.0062 (0.0136)  time: 0.2703  data: 0.0146  max mem: 1849
# Epoch: [2]  [299/300]  eta: 0:00:00  lr: 0.005000  loss: 0.3233 (0.3929)  loss_classifier: 0.0278 (0.0423)  loss_box_reg: 0.0583 (0.0714)  loss_mask: 0.2006 (0.2597)  loss_objectness: 0.0045 (0.0057)  loss_rpn_box_reg: 0.0100 (0.0137)  time: 0.2663  data: 0.0138  max mem: 1849
# Epoch: [2] Total time: 0:01:21 (0.2706 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:24  model_time: 0.1126 (0.1126)  evaluator_time: 0.0039 (0.0039)  time: 0.1230  data: 0.0061  max mem: 1849
# Test:  [100/200]  eta: 0:00:12  model_time: 0.1199 (0.1153)  evaluator_time: 0.0042 (0.0042)  time: 0.1306  data: 0.0067  max mem: 1849
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1186 (0.1163)  evaluator_time: 0.0037 (0.0039)  time: 0.1270  data: 0.0073  max mem: 1849
# Test: Total time: 0:00:25 (0.1274 s / it)
# Averaged stats: model_time: 0.1186 (0.1163)  evaluator_time: 0.0037 (0.0039)
# Accumulating evaluation results...
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.515
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.891
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.533
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.530
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.522
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.548
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.654
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.654
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.657
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.655
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.891
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.663
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.420
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.581
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.690
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.690
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.691
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.691

# %% [markdown]
# In order to analyze the output, you'll need to know what an IoU score is. You can read this blog: https://www.pyimagesearch.com/2016/11/07/intersection-over-union-iou-for-object-detection/

# %% [markdown]
# ## Question 8 [10%]
#
# In an image (grey box) of size 12x16, there is an object whose ground truth mask is the box with the dashed edge (green color) and the model's predicted mask is the box with the dash-dotted edge (red color). Calculate the IoU score for this prediction.
#
# ![Image](../shared/HW3/img/plot.png)

# %% [markdown]
# #### Answer :
#
# IoU = area overlap/area union = (14-10) * (10-5) / ((15-9) * (11-4)-2)= 20 / 40 = 0.5

# %% [markdown]
# Let's see the model's prediction for a sample from the test set.

# %%
img, target = dataset_test[1]

# put the model in evaluation mode
model_p2.eval()

with torch.no_grad():
    prediction = model_p2([img.to(device)])

# %% [markdown]
# Here's the sample image.

# %%
Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F24C882F610>

# %% [markdown]
# And here's the mask generated by the finetuned model.

# %%
Image.fromarray(prediction[0]['masks'][0, 0].mul(255).byte().cpu().numpy())
# Out:
# <PIL.Image.Image image mode=L size=259x194 at 0x7F24D9977950>

# %% [markdown]
# # 3. Finetuning the Entire Network

# %% [markdown]
# Let's see what happens when we fine-tune the entire network. That is, instead of just learning the weights in the final layers, we'll let the weights of the entire network change during the training process.

# %%
model_p3 = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)

# %% [markdown]
# ## Question 9 [5%]
#
# Just like in question 5, we're interested in fine-tuning the pretrained model for our new dataset, so we will again need to modify its box predictor (FastRCNNPredictor) and its mask predictor (MaskRCNNPredictor) to match with our new dataset. Complete the code cell below. Hint: This is exactly the same as question 5.

# %%
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

# Our new dataset has 3 classes: butterfly, squirrel and background
num_classes = 3

# Get number of input features for the classifier
in_features = model_p3.roi_heads.box_predictor.cls_score.in_features

# TODO: replace the pre-trained head with a new one
model_p3.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

# Get number of input features for the mask predictor
in_features_mask = model_p3.roi_heads.mask_predictor.conv5_mask.in_channels
hidden_layer = 256

# TODO: replace the mask predictor with a new one
model_p3.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask, hidden_layer, num_classes)

# %% [markdown]
# Again, let's ensure that we're using the GPU by printing the device info. This finetuning process takes even longer because we have more trainable parameters, hence there will be more computations.

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print("Using : ", device)

model_p3 = model_p3.to(device)
# Out:
# Using :  cuda

# %% [markdown]
# We'll use the same optimizer and learning rate scheduler as before.

# %%
params = [p for p in model_p3.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                step_size=3,
                                                gamma=0.1)

# %% [markdown]
# Let's start the finetuning process.

# %%
num_epochs = 3

from engine import train_one_epoch, evaluate

for epoch in range(num_epochs):
    print("Epoch", epoch)
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model_p3, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model_p3, data_loader_test, device=device)
# Out:
# Epoch 0
# Epoch: [0]  [  0/300]  eta: 0:03:09  lr: 0.000022  loss: 5.2555 (5.2555)  loss_classifier: 1.1308 (1.1308)  loss_box_reg: 0.1429 (0.1429)  loss_mask: 3.9763 (3.9763)  loss_objectness: 0.0042 (0.0042)  loss_rpn_box_reg: 0.0014 (0.0014)  time: 0.6313  data: 0.0172  max mem: 2590
# Epoch: [0]  [ 10/300]  eta: 0:02:54  lr: 0.000189  loss: 3.2454 (3.6547)  loss_classifier: 0.9876 (0.8974)  loss_box_reg: 0.1429 (0.1680)  loss_mask: 2.2523 (2.5715)  loss_objectness: 0.0047 (0.0074)  loss_rpn_box_reg: 0.0081 (0.0105)  time: 0.6027  data: 0.0151  max mem: 4011
# Epoch: [0]  [ 20/300]  eta: 0:02:42  lr: 0.000356  loss: 1.6372 (2.4281)  loss_classifier: 0.4396 (0.5721)  loss_box_reg: 0.1392 (0.1558)  loss_mask: 1.0131 (1.6804)  loss_objectness: 0.0048 (0.0085)  loss_rpn_box_reg: 0.0069 (0.0113)  time: 0.5795  data: 0.0147  max mem: 4011
# Epoch: [0]  [ 30/300]  eta: 0:02:38  lr: 0.000523  loss: 0.8222 (1.9016)  loss_classifier: 0.1018 (0.4165)  loss_box_reg: 0.1107 (0.1390)  loss_mask: 0.6141 (1.3251)  loss_objectness: 0.0067 (0.0094)  loss_rpn_box_reg: 0.0055 (0.0116)  time: 0.5790  data: 0.0137  max mem: 4011
# Epoch: [0]  [ 40/300]  eta: 0:02:31  lr: 0.000690  loss: 0.6564 (1.5836)  loss_classifier: 0.0951 (0.3492)  loss_box_reg: 0.1111 (0.1375)  loss_mask: 0.3813 (1.0777)  loss_objectness: 0.0047 (0.0087)  loss_rpn_box_reg: 0.0060 (0.0104)  time: 0.5849  data: 0.0140  max mem: 4011
# Epoch: [0]  [ 50/300]  eta: 0:02:25  lr: 0.000857  loss: 0.5200 (1.3739)  loss_classifier: 0.0911 (0.2981)  loss_box_reg: 0.1121 (0.1325)  loss_mask: 0.2879 (0.9247)  loss_objectness: 0.0030 (0.0077)  loss_rpn_box_reg: 0.0057 (0.0108)  time: 0.5769  data: 0.0141  max mem: 4011
# Epoch: [0]  [ 60/300]  eta: 0:02:19  lr: 0.001024  loss: 0.4535 (1.2355)  loss_classifier: 0.0624 (0.2635)  loss_box_reg: 0.1024 (0.1332)  loss_mask: 0.2541 (0.8204)  loss_objectness: 0.0039 (0.0072)  loss_rpn_box_reg: 0.0057 (0.0111)  time: 0.5827  data: 0.0139  max mem: 4011
# Epoch: [0]  [ 70/300]  eta: 0:02:14  lr: 0.001191  loss: 0.4237 (1.1263)  loss_classifier: 0.0612 (0.2352)  loss_box_reg: 0.1092 (0.1298)  loss_mask: 0.2541 (0.7427)  loss_objectness: 0.0032 (0.0067)  loss_rpn_box_reg: 0.0070 (0.0119)  time: 0.5906  data: 0.0142  max mem: 4011
# Epoch: [0]  [ 80/300]  eta: 0:02:09  lr: 0.001358  loss: 0.3997 (1.0399)  loss_classifier: 0.0594 (0.2150)  loss_box_reg: 0.1054 (0.1266)  loss_mask: 0.2101 (0.6781)  loss_objectness: 0.0032 (0.0064)  loss_rpn_box_reg: 0.0140 (0.0138)  time: 0.5991  data: 0.0141  max mem: 4011
# Epoch: [0]  [ 90/300]  eta: 0:02:03  lr: 0.001525  loss: 0.3935 (0.9740)  loss_classifier: 0.0564 (0.2000)  loss_box_reg: 0.1054 (0.1268)  loss_mask: 0.1916 (0.6266)  loss_objectness: 0.0034 (0.0061)  loss_rpn_box_reg: 0.0173 (0.0145)  time: 0.6013  data: 0.0146  max mem: 4011
# Epoch: [0]  [100/300]  eta: 0:01:58  lr: 0.001692  loss: 0.4090 (0.9378)  loss_classifier: 0.0597 (0.1869)  loss_box_reg: 0.1072 (0.1253)  loss_mask: 0.2214 (0.6057)  loss_objectness: 0.0033 (0.0061)  loss_rpn_box_reg: 0.0091 (0.0139)  time: 0.6047  data: 0.0154  max mem: 4011
# Epoch: [0]  [110/300]  eta: 0:01:52  lr: 0.001859  loss: 0.5160 (0.8992)  loss_classifier: 0.0598 (0.1763)  loss_box_reg: 0.0999 (0.1244)  loss_mask: 0.2738 (0.5783)  loss_objectness: 0.0034 (0.0061)  loss_rpn_box_reg: 0.0068 (0.0142)  time: 0.5964  data: 0.0156  max mem: 4011
# Epoch: [0]  [120/300]  eta: 0:01:46  lr: 0.002026  loss: 0.4932 (0.8627)  loss_classifier: 0.0558 (0.1677)  loss_box_reg: 0.1019 (0.1252)  loss_mask: 0.2480 (0.5503)  loss_objectness: 0.0032 (0.0058)  loss_rpn_box_reg: 0.0074 (0.0137)  time: 0.5929  data: 0.0151  max mem: 4011
# Epoch: [0]  [130/300]  eta: 0:01:40  lr: 0.002193  loss: 0.4688 (0.8319)  loss_classifier: 0.0558 (0.1601)  loss_box_reg: 0.1091 (0.1257)  loss_mask: 0.2073 (0.5262)  loss_objectness: 0.0030 (0.0056)  loss_rpn_box_reg: 0.0092 (0.0142)  time: 0.6001  data: 0.0146  max mem: 4011
# Epoch: [0]  [140/300]  eta: 0:01:34  lr: 0.002361  loss: 0.4724 (0.8144)  loss_classifier: 0.0541 (0.1529)  loss_box_reg: 0.1180 (0.1254)  loss_mask: 0.2428 (0.5166)  loss_objectness: 0.0019 (0.0055)  loss_rpn_box_reg: 0.0075 (0.0140)  time: 0.5965  data: 0.0147  max mem: 4011
# Test:  [100/200]  eta: 0:00:12  model_time: 0.1202 (0.1146)  evaluator_time: 0.0043 (0.0041)  time: 0.1303  data: 0.0067  max mem: 4290
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1194 (0.1172)  evaluator_time: 0.0043 (0.0042)  time: 0.1297  data: 0.0075  max mem: 4290
# Test: Total time: 0:00:25 (0.1286 s / it)
# Averaged stats: model_time: 0.1194 (0.1172)  evaluator_time: 0.0043 (0.0042)
# Accumulating evaluation results...
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.482
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.896
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.483
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.486
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.494
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.511
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.598
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.598
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.599
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.599
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.581
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.876
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.648
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.490
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.619
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.607
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.691
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.691
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.732
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.683
# Epoch 1
# Epoch: [1]  [  0/300]  eta: 0:03:01  lr: 0.005000  loss: 0.5018 (0.5018)  loss_classifier: 0.0726 (0.0726)  loss_box_reg: 0.1434 (0.1434)  loss_mask: 0.2807 (0.2807)  loss_objectness: 0.0013 (0.0013)  loss_rpn_box_reg: 0.0038 (0.0038)  time: 0.6042  data: 0.0170  max mem: 4290
# Epoch: [1]  [ 10/300]  eta: 0:03:01  lr: 0.005000  loss: 0.3679 (0.3773)  loss_classifier: 0.0330 (0.0354)  loss_box_reg: 0.0530 (0.0605)  loss_mask: 0.2510 (0.2640)  loss_objectness: 0.0020 (0.0031)  loss_rpn_box_reg: 0.0075 (0.0143)  time: 0.6263  data: 0.0149  max mem: 4290
# Epoch: [1]  [ 20/300]  eta: 0:02:50  lr: 0.005000  loss: 0.3436 (0.4164)  loss_classifier: 0.0328 (0.0365)  loss_box_reg: 0.0533 (0.0617)  loss_mask: 0.2348 (0.3003)  loss_objectness: 0.0022 (0.0029)  loss_rpn_box_reg: 0.0096 (0.0151)  time: 0.6084  data: 0.0146  max mem: 4290
# Epoch: [1]  [ 30/300]  eta: 0:02:44  lr: 0.005000  loss: 0.3410 (0.3930)  loss_classifier: 0.0336 (0.0369)  loss_box_reg: 0.0607 (0.0654)  loss_mask: 0.2222 (0.2746)  loss_objectness: 0.0024 (0.0034)  loss_rpn_box_reg: 0.0055 (0.0127)  time: 0.5972  data: 0.0140  max mem: 4290
# Epoch: [1]  [ 40/300]  eta: 0:02:35  lr: 0.005000  loss: 0.3028 (0.3766)  loss_classifier: 0.0336 (0.0356)  loss_box_reg: 0.0574 (0.0625)  loss_mask: 0.1877 (0.2607)  loss_objectness: 0.0019 (0.0031)  loss_rpn_box_reg: 0.0089 (0.0147)  time: 0.5913  data: 0.0135  max mem: 4290
# Epoch: [1]  [ 50/300]  eta: 0:02:28  lr: 0.005000  loss: 0.2967 (0.3706)  loss_classifier: 0.0300 (0.0358)  loss_box_reg: 0.0535 (0.0627)  loss_mask: 0.2024 (0.2552)  loss_objectness: 0.0018 (0.0031)  loss_rpn_box_reg: 0.0100 (0.0139)  time: 0.5725  data: 0.0132  max mem: 4290
# Test:  [100/200]  eta: 0:00:12  model_time: 0.1168 (0.1116)  evaluator_time: 0.0028 (0.0030)  time: 0.1248  data: 0.0064  max mem: 4661
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1175 (0.1143)  evaluator_time: 0.0038 (0.0033)  time: 0.1275  data: 0.0073  max mem: 4661
# Test: Total time: 0:00:24 (0.1248 s / it)
# Averaged stats: model_time: 0.1175 (0.1143)  evaluator_time: 0.0038 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.555
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.893
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.473
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.576
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.577
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.657
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.658
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.633
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.663
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.650
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.891
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.734
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.494
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.686
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.734
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.736
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.741
# Epoch 2
# Epoch: [2]  [  0/300]  eta: 0:03:30  lr: 0.005000  loss: 0.3944 (0.3944)  loss_classifier: 0.0336 (0.0336)  loss_box_reg: 0.0794 (0.0794)  loss_mask: 0.2566 (0.2566)  loss_objectness: 0.0013 (0.0013)  loss_rpn_box_reg: 0.0236 (0.0236)  time: 0.7018  data: 0.0155  max mem: 4661
# Epoch: [2]  [ 10/300]  eta: 0:02:55  lr: 0.005000  loss: 0.2988 (0.3343)  loss_classifier: 0.0362 (0.0415)  loss_box_reg: 0.0600 (0.0593)  loss_mask: 0.1759 (0.2189)  loss_objectness: 0.0015 (0.0038)  loss_rpn_box_reg: 0.0098 (0.0109)  time: 0.6063  data: 0.0137  max mem: 4661
# Epoch: [2]  [ 20/300]  eta: 0:02:54  lr: 0.005000  loss: 0.2394 (0.3068)  loss_classifier: 0.0362 (0.0410)  loss_box_reg: 0.0570 (0.0617)  loss_mask: 0.1586 (0.1902)  loss_objectness: 0.0012 (0.0031)  loss_rpn_box_reg: 0.0060 (0.0109)  time: 0.6181  data: 0.0138  max mem: 4661
# Epoch: [2]  [ 30/300]  eta: 0:02:51  lr: 0.005000  loss: 0.2294 (0.3104)  loss_classifier: 0.0272 (0.0403)  loss_box_reg: 0.0563 (0.0640)  loss_mask: 0.1435 (0.1943)  loss_objectness: 0.0012 (0.0028)  loss_rpn_box_reg: 0.0049 (0.0091)  time: 0.6509  data: 0.0144  max mem: 4661
# Epoch: [2]  [ 40/300]  eta: 0:02:44  lr: 0.005000  loss: 0.2312 (0.2961)  loss_classifier: 0.0313 (0.0391)  loss_box_reg: 0.0501 (0.0621)  loss_mask: 0.1384 (0.1819)  loss_objectness: 0.0020 (0.0027)  loss_rpn_box_reg: 0.0057 (0.0103)  time: 0.6442  data: 0.0145  max mem: 4661
# Epoch: [2]  [ 50/300]  eta: 0:02:39  lr: 0.005000  loss: 0.2291 (0.2862)  loss_classifier: 0.0257 (0.0371)  loss_box_reg: 0.0436 (0.0596)  loss_mask: 0.1232 (0.1766)  loss_objectness: 0.0011 (0.0025)  loss_rpn_box_reg: 0.0059 (0.0105)  time: 0.6391  data: 0.0142  max mem: 4661
# Epoch: [2]  [ 60/300]  eta: 0:02:30  lr: 0.005000  loss: 0.2109 (0.2788)  loss_classifier: 0.0212 (0.0356)  loss_box_reg: 0.0379 (0.0573)  loss_mask: 0.1217 (0.1722)  loss_objectness: 0.0010 (0.0024)  loss_rpn_box_reg: 0.0110 (0.0112)  time: 0.6162  data: 0.0143  max mem: 4661
# Epoch: [2]  [ 70/300]  eta: 0:02:25  lr: 0.005000  loss: 0.2036 (0.2706)  loss_classifier: 0.0213 (0.0339)  loss_box_reg: 0.0408 (0.0566)  loss_mask: 0.1331 (0.1668)  loss_objectness: 0.0012 (0.0025)  loss_rpn_box_reg: 0.0110 (0.0109)  time: 0.6272  data: 0.0143  max mem: 4661
# Epoch: [2]  [ 80/300]  eta: 0:02:17  lr: 0.005000  loss: 0.2251 (0.2750)  loss_classifier: 0.0244 (0.0339)  loss_box_reg: 0.0460 (0.0575)  loss_mask: 0.1366 (0.1698)  loss_objectness: 0.0019 (0.0031)  loss_rpn_box_reg: 0.0058 (0.0107)  time: 0.6238  data: 0.0140  max mem: 4661
# Epoch: [2]  [ 90/300]  eta: 0:02:09  lr: 0.005000  loss: 0.2251 (0.2704)  loss_classifier: 0.0244 (0.0332)  loss_box_reg: 0.0457 (0.0556)  loss_mask: 0.1363 (0.1672)  loss_objectness: 0.0020 (0.0031)  loss_rpn_box_reg: 0.0064 (0.0113)  time: 0.5588  data: 0.0134  max mem: 4661
# Epoch: [2]  [100/300]  eta: 0:02:03  lr: 0.005000  loss: 0.1908 (0.2683)  loss_classifier: 0.0207 (0.0322)  loss_box_reg: 0.0467 (0.0553)  loss_mask: 0.1066 (0.1668)  loss_objectness: 0.0008 (0.0029)  loss_rpn_box_reg: 0.0080 (0.0112)  time: 0.5711  data: 0.0131  max mem: 4661
# Epoch: [2]  [110/300]  eta: 0:01:56  lr: 0.005000  loss: 0.2293 (0.2697)  loss_classifier: 0.0229 (0.0322)  loss_box_reg: 0.0530 (0.0558)  loss_mask: 0.1319 (0.1678)  loss_objectness: 0.0008 (0.0029)  loss_rpn_box_reg: 0.0089 (0.0109)  time: 0.6032  data: 0.0137  max mem: 4661
# Epoch: [2]  [120/300]  eta: 0:01:50  lr: 0.005000  loss: 0.2639 (0.2714)  loss_classifier: 0.0285 (0.0319)  loss_box_reg: 0.0453 (0.0544)  loss_mask: 0.1524 (0.1710)  loss_objectness: 0.0021 (0.0029)  loss_rpn_box_reg: 0.0093 (0.0111)  time: 0.5947  data: 0.0139  max mem: 4661
# Epoch: [2]  [130/300]  eta: 0:01:43  lr: 0.005000  loss: 0.2374 (0.2724)  loss_classifier: 0.0248 (0.0318)  loss_box_reg: 0.0427 (0.0544)  loss_mask: 0.1594 (0.1720)  loss_objectness: 0.0021 (0.0029)  loss_rpn_box_reg: 0.0105 (0.0113)  time: 0.5939  data: 0.0142  max mem: 4661
# Epoch: [2]  [140/300]  eta: 0:01:37  lr: 0.005000  loss: 0.2484 (0.2706)  loss_classifier: 0.0249 (0.0316)  loss_box_reg: 0.0471 (0.0543)  loss_mask: 0.1594 (0.1705)  loss_objectness: 0.0016 (0.0030)  loss_rpn_box_reg: 0.0097 (0.0112)  time: 0.5998  data: 0.0147  max mem: 4661
# Epoch: [2]  [150/300]  eta: 0:01:31  lr: 0.005000  loss: 0.2259 (0.2673)  loss_classifier: 0.0183 (0.0307)  loss_box_reg: 0.0427 (0.0538)  loss_mask: 0.1501 (0.1689)  loss_objectness: 0.0016 (0.0029)  loss_rpn_box_reg: 0.0058 (0.0110)  time: 0.6070  data: 0.0141  max mem: 4661
# Epoch: [2]  [160/300]  eta: 0:01:26  lr: 0.005000  loss: 0.2246 (0.2705)  loss_classifier: 0.0212 (0.0310)  loss_box_reg: 0.0435 (0.0543)  loss_mask: 0.1501 (0.1707)  loss_objectness: 0.0014 (0.0031)  loss_rpn_box_reg: 0.0046 (0.0114)  time: 0.6521  data: 0.0139  max mem: 4661
# Epoch: [2]  [170/300]  eta: 0:01:19  lr: 0.005000  loss: 0.2195 (0.2674)  loss_classifier: 0.0279 (0.0310)  loss_box_reg: 0.0407 (0.0538)  loss_mask: 0.1320 (0.1682)  loss_objectness: 0.0014 (0.0031)  loss_rpn_box_reg: 0.0093 (0.0113)  time: 0.6333  data: 0.0150  max mem: 4661
# Epoch: [2]  [180/300]  eta: 0:01:13  lr: 0.005000  loss: 0.2056 (0.2670)  loss_classifier: 0.0218 (0.0307)  loss_box_reg: 0.0387 (0.0536)  loss_mask: 0.1258 (0.1684)  loss_objectness: 0.0012 (0.0031)  loss_rpn_box_reg: 0.0073 (0.0112)  time: 0.5640  data: 0.0148  max mem: 4661
# Epoch: [2]  [190/300]  eta: 0:01:06  lr: 0.005000  loss: 0.2433 (0.2699)  loss_classifier: 0.0248 (0.0317)  loss_box_reg: 0.0462 (0.0548)  loss_mask: 0.1329 (0.1694)  loss_objectness: 0.0012 (0.0030)  loss_rpn_box_reg: 0.0051 (0.0110)  time: 0.5677  data: 0.0156  max mem: 4661
# Epoch: [2]  [200/300]  eta: 0:01:00  lr: 0.005000  loss: 0.2244 (0.2703)  loss_classifier: 0.0292 (0.0315)  loss_box_reg: 0.0432 (0.0540)  loss_mask: 0.1417 (0.1710)  loss_objectness: 0.0011 (0.0030)  loss_rpn_box_reg: 0.0075 (0.0109)  time: 0.6056  data: 0.0159  max mem: 4661
# Epoch: [2]  [210/300]  eta: 0:00:54  lr: 0.005000  loss: 0.2244 (0.2682)  loss_classifier: 0.0235 (0.0311)  loss_box_reg: 0.0401 (0.0537)  loss_mask: 0.1359 (0.1693)  loss_objectness: 0.0024 (0.0031)  loss_rpn_box_reg: 0.0078 (0.0110)  time: 0.5928  data: 0.0141  max mem: 4661
# Epoch: [2]  [220/300]  eta: 0:00:48  lr: 0.005000  loss: 0.2302 (0.2663)  loss_classifier: 0.0184 (0.0306)  loss_box_reg: 0.0481 (0.0534)  loss_mask: 0.1322 (0.1683)  loss_objectness: 0.0023 (0.0030)  loss_rpn_box_reg: 0.0078 (0.0110)  time: 0.5817  data: 0.0134  max mem: 4661
# Epoch: [2]  [230/300]  eta: 0:00:42  lr: 0.005000  loss: 0.2068 (0.2631)  loss_classifier: 0.0171 (0.0303)  loss_box_reg: 0.0346 (0.0526)  loss_mask: 0.1305 (0.1661)  loss_objectness: 0.0019 (0.0030)  loss_rpn_box_reg: 0.0098 (0.0112)  time: 0.5994  data: 0.0136  max mem: 4661
# Epoch: [2]  [240/300]  eta: 0:00:36  lr: 0.005000  loss: 0.2130 (0.2661)  loss_classifier: 0.0201 (0.0299)  loss_box_reg: 0.0419 (0.0527)  loss_mask: 0.1290 (0.1694)  loss_objectness: 0.0017 (0.0029)  loss_rpn_box_reg: 0.0086 (0.0110)  time: 0.6035  data: 0.0139  max mem: 4661
# Epoch: [2]  [250/300]  eta: 0:00:30  lr: 0.005000  loss: 0.2594 (0.2664)  loss_classifier: 0.0214 (0.0299)  loss_box_reg: 0.0439 (0.0523)  loss_mask: 0.1694 (0.1704)  loss_objectness: 0.0017 (0.0030)  loss_rpn_box_reg: 0.0063 (0.0109)  time: 0.5968  data: 0.0140  max mem: 4661
# Epoch: [2]  [260/300]  eta: 0:00:24  lr: 0.005000  loss: 0.2206 (0.2643)  loss_classifier: 0.0214 (0.0296)  loss_box_reg: 0.0417 (0.0520)  loss_mask: 0.1318 (0.1690)  loss_objectness: 0.0024 (0.0030)  loss_rpn_box_reg: 0.0044 (0.0108)  time: 0.5869  data: 0.0138  max mem: 4661
# Epoch: [2]  [270/300]  eta: 0:00:18  lr: 0.005000  loss: 0.2172 (0.2634)  loss_classifier: 0.0219 (0.0297)  loss_box_reg: 0.0447 (0.0526)  loss_mask: 0.1261 (0.1674)  loss_objectness: 0.0014 (0.0029)  loss_rpn_box_reg: 0.0057 (0.0108)  time: 0.6105  data: 0.0148  max mem: 4661
# Epoch: [2]  [280/300]  eta: 0:00:12  lr: 0.005000  loss: 0.2381 (0.2651)  loss_classifier: 0.0246 (0.0302)  loss_box_reg: 0.0624 (0.0530)  loss_mask: 0.1355 (0.1681)  loss_objectness: 0.0014 (0.0029)  loss_rpn_box_reg: 0.0077 (0.0109)  time: 0.6273  data: 0.0157  max mem: 4661
# Epoch: [2]  [290/300]  eta: 0:00:06  lr: 0.005000  loss: 0.2302 (0.2651)  loss_classifier: 0.0220 (0.0298)  loss_box_reg: 0.0355 (0.0524)  loss_mask: 0.1373 (0.1687)  loss_objectness: 0.0027 (0.0031)  loss_rpn_box_reg: 0.0067 (0.0111)  time: 0.6047  data: 0.0144  max mem: 4661
# Epoch: [2]  [299/300]  eta: 0:00:00  lr: 0.005000  loss: 0.2594 (0.2685)  loss_classifier: 0.0229 (0.0298)  loss_box_reg: 0.0352 (0.0525)  loss_mask: 0.1459 (0.1718)  loss_objectness: 0.0029 (0.0032)  loss_rpn_box_reg: 0.0109 (0.0113)  time: 0.6069  data: 0.0142  max mem: 4661
# Epoch: [2] Total time: 0:03:02 (0.6067 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:23  model_time: 0.1089 (0.1089)  evaluator_time: 0.0027 (0.0027)  time: 0.1177  data: 0.0057  max mem: 4661
# Test:  [100/200]  eta: 0:00:12  model_time: 0.1176 (0.1113)  evaluator_time: 0.0026 (0.0026)  time: 0.1241  data: 0.0066  max mem: 4661
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1166 (0.1134)  evaluator_time: 0.0034 (0.0029)  time: 0.1251  data: 0.0076  max mem: 4661
# Test: Total time: 0:00:24 (0.1234 s / it)
# Averaged stats: model_time: 0.1166 (0.1134)  evaluator_time: 0.0034 (0.0029)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.632
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.945
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.742
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.523
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.625
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.709
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.709
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.662
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.721
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.665
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.919
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.760
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.516
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.696
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.668
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.732
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.732

# %% [markdown]
# We'll generate the output for the same image, but this time with the new finetuned model.

# %%
img, target = dataset_test[1]

# put the model in evaluation mode
model_p3.eval()
with torch.no_grad():
    prediction = model_p3([img.to(device)])

Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F24C880B350>

# %% [markdown]
# Here's the predicted image.

# %%
Image.fromarray(prediction[0]['masks'][0, 0].mul(255).byte().cpu().numpy())
# Out:
# <PIL.Image.Image image mode=L size=259x194 at 0x7F24CB252090>

# %% [markdown]
# ## Question 10 [5%]
#
# Does this model perform better than the trained model after Q7? Explain why.

# %% [markdown]
# #### Answer :
# Yes, this model (model_p3) seems to perform better than the trained model after Q7 (model_p2). From observation, the mask image from model_p3 masks the image more boldly than model_p2.
# We can also obsereve from the evaluation results that the precision and recall scores for the IoU metrics of model_p3 are greater than those for model_p2, on average. This means that model_p3 returns more correctly-identified image masks than model_p2.
# This result could be because in model_p3 we are fine-tuning and training the whole network while model_p2 is restricted to just training the final layers. Training the entire network improves model_p3's ability to learn as the model is more open to learn and thus perform better for the image segmentation task.

# %% [markdown]
# ## Question 11 [10 %]
#
# What is the advantage of using CONV layers over FC/Dense layers?

# %% [markdown]
# #### Answer :
#
# An advantage of using CONV layers over FC/Dense layers is that it's easier to train a network with convolutional layer because the layers use significantly fewer parameters than dense layers and the number of connections and weights between layers is smaller. This makes the convolutional network more trainable especially for image processing which has lots of data.
# Additionally, algorithms like backpropogation are more feasible to run on a smaller, finite number of parameters from convolutional layers than an exponential number of parameters that dense layers may produce.
# Models with convolutional layers may also run easier on many computers that have resource constraints.

# %% [markdown]
# # 4. Extra Credit Questions

# %% [markdown]
# ## Question 12 [10 points]
#
# Can fully convolutional networks (FCN) be used for object detection? In Mask-RCNN we have 3 branches — mask, classification, and bounding box regression — out of which the last 2 have fully connected (FC) layers. Can this entire pipeline be replaced by a fully convolutional network? If possible, give 1 or 2 networks to support your claim.

# %% [markdown]
# #### Answer :
#
# Yes, fully convolutional networks (FCN) be used for object detection such that the entire pipeline (mask, classification, and bounding box regression) can be replaced by a fully convolution network. One such network is End-to-End Object Detection with Fully Convolutional Network as discussed in this article: https://arxiv.org/pdf/2012.03544.pdf. It uses a one-to-one label assignment and a 3D Max Filtering to bridge the gap between fully convolutional network and end-to-end object detection.
